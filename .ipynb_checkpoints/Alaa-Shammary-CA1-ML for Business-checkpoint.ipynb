# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import LabelEncoder

from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import silhouette_score

import warnings
warnings.filterwarnings('ignore')

# %%
d1 = pd.read_excel('data.xlsx',0)

# %%
d1.head()
# Out:
#   Invoice StockCode                          Description  Quantity  \
# 0  489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1  489434    79323P                   PINK CHERRY LIGHTS        12
# 2  489434    79323W                  WHITE CHERRY LIGHTS        12
# 3  489434     22041         RECORD FRAME 7" SINGLE SIZE         48
# 4  489434     21232       STRAWBERRY CERAMIC TRINKET BOX        24
#
#           InvoiceDate  Price  Customer ID         Country
# 0 2009-12-01 07:45:00   6.95      13085.0  United Kingdom
# 1 2009-12-01 07:45:00   6.75      13085.0  United Kingdom
# 2 2009-12-01 07:45:00   6.75      13085.0  United Kingdom
# 3 2009-12-01 07:45:00   2.10      13085.0  United Kingdom
# 4 2009-12-01 07:45:00   1.25      13085.0  United Kingdom

# %%
d2 = pd.read_excel('data.xlsx',1)

# %%
d2.head()
# Out:
#   Invoice StockCode                          Description  Quantity  \
# 0  536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1  536365     71053                  WHITE METAL LANTERN         6
# 2  536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3  536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4  536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  Price  Customer ID         Country
# 0 2010-12-01 08:26:00   2.55      17850.0  United Kingdom
# 1 2010-12-01 08:26:00   3.39      17850.0  United Kingdom
# 2 2010-12-01 08:26:00   2.75      17850.0  United Kingdom
# 3 2010-12-01 08:26:00   3.39      17850.0  United Kingdom
# 4 2010-12-01 08:26:00   3.39      17850.0  United Kingdom

# %%
data_df = pd.concat([d1,d2])

# %%
pd.set_option('display.max_rows', None)
data_df.head(100)
# Out:
#    Invoice StockCode                          Description  Quantity  \
# 0   489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1   489434    79323P                   PINK CHERRY LIGHTS        12
# 2   489434    79323W                  WHITE CHERRY LIGHTS        12
# 3   489434     22041         RECORD FRAME 7" SINGLE SIZE         48
# 4   489434     21232       STRAWBERRY CERAMIC TRINKET BOX        24
# 5   489434     22064           PINK DOUGHNUT TRINKET POT         24
# 6   489434     21871                  SAVE THE PLANET MUG        24
# 7   489434     21523   FANCY FONT HOME SWEET HOME DOORMAT        10
# 8   489435     22350                            CAT BOWL         12
# 9   489435     22349       DOG BOWL , CHASING BALL DESIGN        12
# 10  489435     22195         HEART MEASURING SPOONS LARGE        24
# 11  489435     22353   LUNCHBOX WITH CUTLERY FAIRY CAKES         12
# 12  489436    48173C                DOOR MAT BLACK FLOCK         10
# 13  489436     21755             LOVE BUILDING BLOCK WORD        18
# 14  489436     21754             HOME BUILDING BLOCK WORD         3
# 15  489436     84879        ASSORTED COLOUR BIRD ORNAMENT        16
# 16  489436     22119           PEACE WOODEN BLOCK LETTERS         3
# 17  489436     22142         CHRISTMAS CRAFT WHITE FAIRY         12
# 18  489436     22296            HEART IVORY TRELLIS LARGE        12
# 19  489436     22295            HEART FILIGREE DOVE LARGE        12
# 20  489436     22109         FULL ENGLISH BREAKFAST PLATE        16
# 21  489436     22107                   PIZZA PLATE IN BOX         4
# 22  489436     22194               BLACK DINER WALL CLOCK         2
# 23  489436    35004B          SET OF 3 BLACK FLYING DUCKS        12
# 24  489436     82582            AREA PATROLLED METAL SIGN        12
# 25  489436     21181        PLEASE ONE PERSON  METAL SIGN        12
# 26  489436     21756             BATH BUILDING BLOCK WORD         3
# 27  489436     21333                  CLASSIC WHITE FRAME         6
# 28  489436    84596F         SMALL MARSHMALLOWS PINK BOWL         8
# 29  489436    84596L       BISCUITS SMALL BOWL LIGHT BLUE         8
# 30  489436     22111         SCOTTIE DOG HOT WATER BOTTLE        24
# 31  489437     22143    CHRISTMAS CRAFT HEART DECORATIONS         6
# 32  489437     22145      CHRISTMAS CRAFT HEART STOCKING          6
# 33  489437     22130     PARTY CONE CHRISTMAS DECORATION         12
# 34  489437     21364             PEACE SMALL WOOD LETTERS         2
# 35  489437     21360               JOY LARGE WOOD LETTERS         1
# 36  489437     21351             CINAMMON & ORANGE WREATH         2
# 37  489437     21352        EUCALYPTUS & PINECONE  WREATH         2
# 38  489437     35400          WOODEN BOX ADVENT CALENDAR          2
# 39  489437     20695                  FLORAL BLUE MONSTER         3
# 40  489437     37370           RETRO COFFEE MUGS ASSORTED        12
# 41  489437     10002          INFLATABLE POLITICAL GLOBE         12
# 42  489437    84507B           STRIPES DESIGN MONKEY DOLL         6
# 43  489437     20703              BLUE PADDED SOFT MOBILE         3
# 44  489437     21987           PACK OF 6 SKULL PAPER CUPS        12
# 45  489437     21989       PACK OF 20 SKULL PAPER NAPKINS        12
# 46  489437    84970S    HANGING HEART ZINC T-LIGHT HOLDER        12
# 47  489437     20971     PINK BLUE FELT CRAFT TRINKET BOX        12
# 48  489437     22271                 FELTCRAFT DOLL ROSIE         6
# 49  489437     22272                 FELTCRAFT DOLL MARIA         6
# 50  489437     22274                 FELTCRAFT DOLL EMILY         6
# 51  489437     21912             VINTAGE SNAKES & LADDERS         4
# 52  489437     22111         SCOTTIE DOG HOT WATER BOTTLE         3
# 53  489437     22112           CHOCOLATE HOT WATER BOTTLE         3
# 54  489438     21329              DINOSAURS  WRITING SET         28
# 55  489438     21252       SET OF MEADOW  FLOWER STICKERS        30
# 56  489438     21100       CHARLIE AND LOLA CHARLOTTE BAG        30
# 57  489438     21033      JUMBO BAG CHARLIE AND LOLA TOYS        30
# 58  489438     20711                      JUMBO BAG TOYS         60
# 59  489438     21410      COUNTRY COTTAGE  DOORSTOP GREEN        32
# 60  489438     21411          GINGHAM HEART  DOORSTOP RED        32
# 61  489438    84031A   CHARLIE+LOLA RED HOT WATER BOTTLE         56
# 62  489438    84031B  CHARLIE LOLA BLUE HOT WATER BOTTLE         56
# 63  489438    84032A   CHARLIE+LOLA PINK HOT WATER BOTTLE        60
# 64  489438    84032B  CHARLIE + LOLA RED HOT WATER BOTTLE        56
# 65  489438    84519A      TOMATO CHARLIE+LOLA COASTER SET        56
# 66  489438    84519B      CARROT CHARLIE+LOLA COASTER SET        60
# 67  489438    85132A         CHARLIE + LOLA BISCUITS TINS        60
# 68  489438    85132C        CHARLIE AND LOLA FIGURES TINS        60
# 69  489438    85183A   CHARLIE & LOLA WASTEPAPER BIN BLUE        60
# 70  489438    85183B  CHARLIE & LOLA WASTEPAPER BIN FLORA        60
# 71  489439     22065       CHRISTMAS PUDDING TRINKET POT         12
# 72  489439     22138        BAKING SET 9 PIECE RETROSPOT          9
# 73  489439     22139    RETRO SPOT TEA SET CERAMIC 11 PC          9
# 74  489439     22352     LUNCHBOX WITH CUTLERY RETROSPOT         12
# 75  489439    85014A     BLACK/BLUE DOTS RUFFLED UMBRELLA         3
2009-12-01 09:24:00   2.40      18102.0  United Kingdom
# 70 2009-12-01 09:24:00   2.40      18102.0  United Kingdom
# 71 2009-12-01 09:28:00   1.45      12682.0          France
# 72 2009-12-01 09:28:00   4.95      12682.0          France
# 73 2009-12-01 09:28:00   4.95      12682.0          France
# 74 2009-12-01 09:28:00   2.55      12682.0          France
# 75 2009-12-01 09:28:00   5.95      12682.0          France
# 76 2009-12-01 09:28:00   5.95      12682.0          France
# 77 2009-12-01 09:28:00   0.42      12682.0          France
# 78 2009-12-01 09:28:00   0.42      12682.0          France
# 79 2009-12-01 09:28:00   1.95      12682.0          France
# 80 2009-12-01 09:28:00   1.65      12682.0          France
# 81 2009-12-01 09:28:00   0.65      12682.0          France
# 82 2009-12-01 09:28:00   0.85      12682.0          France
# 83 2009-12-01 09:28:00   0.85      12682.0          France
# 84 2009-12-01 09:28:00   1.65      12682.0          France
# 85 2009-12-01 09:28:00   1.65      12682.0          France
# 86 2009-12-01 09:28:00   4.95      12682.0          France
# 87 2009-12-01 09:28:00   0.85      12682.0          France
# 88 2009-12-01 09:28:00   7.95      12682.0          France
# 89 2009-12-01 09:28:00  18.00      12682.0          France
# 90 2009-12-01 09:43:00   2.55      18087.0  United Kingdom
# 91 2009-12-01 09:43:00   3.75      18087.0  United Kingdom
# 92 2009-12-01 09:44:00   0.72      18087.0  United Kingdom
# 93 2009-12-01 09:44:00   4.25      18087.0  United Kingdom
# 94 2009-12-01 09:44:00   2.95      18087.0  United Kingdom
# 95 2009-12-01 09:44:00   4.25      18087.0  United Kingdom
# 96 2009-12-01 09:46:00   6.75      13635.0  United Kingdom
# 97 2009-12-01 09:46:00   4.95      13635.0  United Kingdom
# 98 2009-12-01 09:46:00   1.65      13635.0  United Kingdom
# 99 2009-12-01 09:46:00   1.25      13635.0  United Kingdom

# %%
data_df.shape
# Out:
# (1067371, 8)

# %%
data_df.describe()
# Out:
#            Quantity         Price    Customer ID
# count  1.067371e+06  1.067371e+06  824364.000000
# mean   9.938898e+00  4.649388e+00   15324.638504
# std    1.727058e+02  1.235531e+02    1697.464450
# min   -8.099500e+04 -5.359436e+04   12346.000000
# 25%    1.000000e+00  1.250000e+00   13975.000000
# 50%    3.000000e+00  2.100000e+00   15255.000000
# 75%    1.000000e+01  4.150000e+00   16797.000000
# max    8.099500e+04  3.897000e+04   18287.000000

# %%
data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1067371 entries, 0 to 541909
# Data columns (total 8 columns):
#  #   Column       Non-Null Count    Dtype
# ---  ------       --------------    -----
#  0   Invoice      1067371 non-null  object
#  1   StockCode    1067371 non-null  object
#  2   Description  1062989 non-null  object
#  3   Quantity     1067371 non-null  int64
#  4   InvoiceDate  1067371 non-null  datetime64[ns]
#  5   Price        1067371 non-null  float64
#  6   Customer ID  824364 non-null   float64
#  7   Country      1067371 non-null  object
# dtypes: datetime64[ns](1), float64(2), int64(1), object(4)
# memory usage: 73.3+ MB

# %%
data_df.isnull().sum()
# Out:
# Invoice             0
# StockCode           0
# Description      4382
# Quantity            0
# InvoiceDate         0
# Price               0
# Customer ID    243007
# Country             0
# dtype: int64

# %%
data_df.isna().sum()
# Out:
# Invoice             0
# StockCode           0
# Description      4382
# Quantity            0
# InvoiceDate         0
# Price               0
# Customer ID    243007
# Country             0
# dtype: int64

# %%
data_df.isnull().sum()
# Out:
# Invoice             0
# StockCode           0
# Description      4382
# Quantity            0
# InvoiceDate         0
# Price               0
# Customer ID    243007
# Country             0
# dtype: int64

# %% [markdown]
# plt.figure(figsize=(10, 6))
# sns.heatmap(data_df.isnull(), cmap='viridis', cbar=False)
# plt.title('Missing Values Heatmap')
# plt.show()

# %% [markdown]
# The forward fill method is used because customer IDs are grouped together, so its more accurate to use the forward method for accuracy of data.

# %%
data_df['Customer ID'].fillna(method='ffill',inplace=True)

# %% [markdown]
# Unknown is used to fill missing values because every product is unique and is text based so the use of the mode or forward fill would create some bias in the dataset analysis.

# %%
data_df['Description'].fillna('Unknown',inplace=True)

# %%
data_df.isnull().sum()
# Out:
# Invoice        0
# StockCode      0
# Description    0
# Quantity       0
# InvoiceDate    0
# Price          0
# Customer ID    0
# Country        0
# dtype: int64

# %%
sample_size = 10000  
random_sample = data_df.sample(n=sample_size, random_state=42)

# %%
random_sample.shape
# Out:
# (10000, 8)

# %%
data_encoded = pd.get_dummies(random_sample, columns=['Country', 'Description'])

# %%
data_encoded['StockCode'].dtype
# Out:
# dtype('O')

# %%
data_encoded['StockCode'] = data_encoded['StockCode'].str.extract('(\d+)')

# %%
missing_values = data_encoded.isna().sum()
print(missing_values)
# Out:
# Invoice                                               0
# StockCode                                          8814
# Quantity                                              0
# InvoiceDate                                           0
# Price                                                 0
# Customer ID                                           0
# Country_Australia                                     0
# Country_Austria                                       0
# Country_Bahrain                                       0
# Country_Belgium                                       0
# Country_Brazil                                        0
# Country_Canada                                        0
# Country_Channel Islands                               0
# Country_Cyprus                                        0
# Country_Denmark                                       0
# Description_72 CAKE CASES DOLLY GIRL DESIGN           0
# Description_72 CAKE CASES VINTAGE CHRISTMAS           0
# Description_72 ROUND PINK DOILIES                     0
# Description_72 SWEETHEART FAIRY CAKE CASES            0
# Description_75 GREEN PETIT FOUR CASES                 0
# Description_ABC TREASURE BOOK BOX                     0
# Description_ABSTRACT CIRCLE JOURNAL                   0
# Description_ABSTRACT CIRCLES SKETCHBOOK               0
# Description_ACRYLIC GEOMETRIC LAMP                    0
# Description_ACRYLIC HANGING JEWEL,BLUE                0
# Description_ACRYLIC JEWEL SNOWFLAKE,PINK              0
# Description_ADVENT CALENDAR GINGHAM SACK              0
# Description_AFGHAN SLIPPER SOCK PAIR                  0
# Description_AGED GLASS SILVER T-LIGHT HOLDER          0
# Description_AIRLINE BAG VINTAGE JET SET RED           0
# Description_AIRLINE BAG VINTAGE JET SET WHITE         0
# Description_AIRLINE BAG VINTAGE TOKYO 78              0
# Description_AIRLINE BAG VINTAGE WORLD CHAMPION        0
# Description_AIRLINE LOUNGE,METAL SIGN                 0
# Description_ALARM CLOCK BAKELIKE CHOCOLATE            0
# Description_ALARM CLOCK BAKELIKE GREEN                0
# Description_ALARM CLOCK BAKELIKE IVORY                0
# Description_ALARM CLOCK BAKELIKE ORANGE               0
# Description_ALARM CLOCK BAKELIKE PINK                 0
# Description_ALARM CLOCK BAKELIKE RED                  0
# Description_ALPHABET HEARTS STICKER SHEET             0
# Description_ALUMINIUM STAMPED HEART                   0
# Description_AMBER 3 BEAD DROP EARRINGS                0
# Description_AMBER CHUNKY GLASS+BEAD NECKLACE          0
# Description_AMBER GLASS BRACELET HEART CHARMS         0
# Description_AMETHYST DROP EARRINGS W LONG BEADS       0
# Description_AMETHYST HOOP EARRING FLORAL LEAF         0
# Description_ANGEL DECORATION 3 BUTTONS                0
# Description_ANGEL DECORATION PAINTED ZINC             0
# Description_ANGEL DECORATION STARS ON DRESS           0
# Description_ANGEL DECORATION WITH LACE PADDED         0
# Description_ANIMAL STICKERS                           0
# Description_ANT COPPER LIME BOUDICCA BRACELET         0
# Description_ANT COPPER PINK BOUDICCA BRACELET         0
# Description_ANT SILVER FUSCHIA BOUDICCA RING          0
# Description_ANT WHITE WIRE HEART SPIRAL               0
# Description_ANTIQUE ALL GLASS CANDLESTICK             0
# Description_ANTIQUE CREAM CUTLERY CUPBOARD            0
# Description_ANTIQUE GLASS DRESSING TABLE POT          0
# Description_ANTIQUE GLASS HEART DECORATION            0
# Description_ANTIQUE GLASS PEDESTAL BOWL               0
# Description_ANTIQUE GLASS RIDGED HANGING BALL         0
# Description_ANTIQUE IVORY WIRE BOWL SMALL             0
# Description_ANTIQUE LILY FAIRY LIGHTS                 0
# Description_ANTIQUE SILVER BOOK MARK WITH BEADS       0
# Description_ANTIQUE SILVER T-LIGHT GLASS              0
# Description_ANTIQUE SILVER TEA GLASS ENGRAVED         0
# Description_ANTIQUE SILVER TEA GLASS ETCHED           0
# Description_ANTIQUE TALL SWIRLGLASS TRINKET POT       0
# Description_APPLE BATH SPONGE                         0
# Description_AQUA BERTIE GLASS BEAD BAG CHARM          0
# Description_AREA PATROLLED METAL SIGN                 0
# Description_ASS FLORAL PRINT MULTI SCREWDRIVER        0
# Description_ASSORTED BOTTLE TOP  MAGNETS              0
# Description_ASSORTED CAKES FRIDGE MAGNETS             0
# Description_ASSORTED COLOUR BIRD ORNAMENT             0
# Description_ASSORTED COLOUR LIZARD SUCTION HOOK       0
# Description_ASSORTED COLOUR METAL CAT                 0
# Description_ASSORTED COLOUR MINI CASES                0
# Description_ASSORTED COLOUR SET 6 TEASPOONS           0
# Description_ASSORTED COLOUR SILK GLASSES CASE         0
# Description_ASSORTED COLOUR SUCTION CUP HOOK          0
# Description_ASSORTED COLOUR T-LIGHT HOLDER            0
# Description_ASSORTED COLOURS SILK FAN                 0
# Description_ASSORTED CREEPY CRAWLIES                  0
# Description_ASSORTED FLORAL SECATEURS                 0
# Description_ASSORTED FLOWER COLOUR "LEIS"             0
# Description_ASSORTED MONKEY SUCTION CUP HOOK          0
# Description_ASSORTED SANSKRIT MINI NOTEBOOK           0
# Description_ASSORTED TUTTI FRUTTI  FOB NOTEBOOK       0
# Description_ASSORTED TUTTI FRUTTI BRACELET            0
# Description_ASSORTED TUTTI FRUTTI HEART BOX           0
# Description_ASSORTED TUTTI FRUTTI KEYRING BALL        0
# Description_ASSORTED TUTTI FRUTTI MIRROR              0
# Description_ASSORTED TUTTI FRUTTI NOTEBOOK            0
# Description_ASSORTED TUTTI FRUTTI PEN                 0
# Description_ASSORTED TUTTI FRUTTI PHOTO FRAME         0
# Description_ASSORTED WHITE EMBOSSED CHINA MUGS        0
# Description_ASSTD DESIGN BUBBLE GUM RING              0
# Description_ASSTD DESIGN RACING CAR PEN               0
# Description_ASSTD MULTICOLOUR CIRCLES MUG             0
# Description_Adjustment by john on 26/01/2010 16       0
# Description_Amazon                                    0
# Description_BABUSHKA LIGHTS STRING OF 10              0
# Description_BABY BOOM RIBBONS                         0
# Description_BABY MOUSE RED GINGHAM DRESS              0
# Description_BAG 125g SWIRLY MARBLES                   0
# Description_BAG 250g SWIRLY MARBLES                   0
# Description_BAG 500g SWIRLY MARBLES                   0
# Description_BAKING MOULD EASTER EGG MILK CHOC         0
# Description_BAKING MOULD EASTER EGG WHITE CHOC        0
# Description_BAKING MOULD HEART MILK CHOCOLATE         0
# Description_BAKING MOULD HEART WHITE CHOCOLATE        0
# Description_BAKING MOULD ROSE MILK CHOCOLATE          0
# Description_BAKING MOULD ROSE WHITE CHOCOLATE         0
# Description_BAKING SET 9 PIECE RETROSPOT              0
# Description_BAKING SET SPACEBOY DESIGN                0
# Description_BALLOON ART MAKE YOUR OWN FLOWERS         0
# Description_BALLOON PUMP WITH 10 BALLOONS             0
# Description_BALLOON WATER BOMB PACK OF 35             0
# Description_BALLOONS  WRITING SET                     0
# Description_BANQUET BIRTHDAY  CARD                    0
# Description_BASKET OF FLOWERS SEWING KIT              0
# Description_BASKET OF TOADSTOOLS                      0
# Description_BATH BUILDING BLOCK WORD                  0
# Description_BATHROOM METAL SIGN                       0
# Description_BATHROOM METAL SIGN                       0
# Description_TV DINNER TRAY VINTAGE PAISLEY            0
# Description_TWO DOOR CURIO CABINET                    0
# Description_This is a test product.                   0
# Description_UNION FLAG WINDSOCK                       0
# Description_UNION JACK FLAG LUGGAGE TAG               0
# Description_UNION JACK FLAG PASSPORT COVER            0
# Description_UNION JACK GUNS & ROSES  DOORMAT          0
# Description_UNION JACK HOT WATER BOTTLE               0
# Description_UNION STRIPE CUSHION COVER                0
# Description_UNION STRIPE WITH FRINGE  HAMMOCK         0
# Description_URBAN BLACK RIBBONS                       0
# Description_URBAN CHIC CHOPSTICKS SET/5               0
# Description_UTILTY CABINET WITH HOOKS                 0
# Description_Unknown                                   0
# Description_VANILLA SCENT CANDLE JEWELLED BOX         0
# Description_VICTORIAN  METAL POSTCARD SPRING          0
# Description_VICTORIAN GLASS HANGING T-LIGHT           0
# Description_VICTORIAN SEWING BOX LARGE                0
# Description_VICTORIAN SEWING BOX MEDIUM               0
# Description_VICTORIAN SEWING BOX SMALL                0
# Description_VICTORIAN SEWING KIT                      0
# Description_VINTAGE  2 METER FOLDING RULER            0
# Description_VINTAGE  2 METRE FOLDING RULER            0
# Description_VINTAGE BEAD COSMETIC BAG                 0
# Description_VINTAGE BEAD NOTEBOOK                     0
# Description_VINTAGE BEAD PINK EVENING BAG             0
# Description_VINTAGE BEAD PINK PURSE                   0
# Description_VINTAGE BEAD PINK SHADE                   0
# Description_VINTAGE BELLS GARLAND                     0
# Description_VINTAGE BILLBOARD DRINK ME MUG            0
# Description_VINTAGE BILLBOARD LOVE/HATE MUG           0
# Description_VINTAGE BILLBOARD MUG                     0
# Description_VINTAGE BILLBOARD TEA MUG                 0
# Description_VINTAGE BLUE KITCHEN CABINET              0
# Description_VINTAGE BLUE TINSEL REEL                  0
# Description_VINTAGE CARAVAN GIFT WRAP                 0
# Description_VINTAGE CARAVAN GREETING CARD             0
# Description_VINTAGE CHRISTMAS BUNTING                 0
# Description_VINTAGE CHRISTMAS GIFT SACK               0
# Description_VINTAGE CHRISTMAS STOCKING                0
# Description_VINTAGE CHRISTMAS TABLECLOTH              0
# Description_VINTAGE CREAM 3 BASKET CAKE STAND         0
# Description_VINTAGE CREAM CAT FOOD CONTAINER          0
# Description_VINTAGE CREAM DOG FOOD CONTAINER          0
# Description_VINTAGE DOILY DELUXE SEWING KIT           0
# Description_VINTAGE DOILY JUMBO BAG RED               0
# Description_VINTAGE DOILY TRAVEL SEWING KIT           0
# Description_VINTAGE EMBOSSED HEART                    0
# Description_VINTAGE GLASS COFFEE CADDY                0
# Description_VINTAGE GLASS T-LIGHT HOLDER              0
# Description_VINTAGE GLASS TEA CADDY                   0
# Description_VINTAGE GOLD TINSEL REEL                  0
# Description_VINTAGE HEADS AND TAILS CARD GAME         0
# Description_VINTAGE KID DOLLY CARD                    0
# Description_VINTAGE KITCHEN PRINT FRUITS              0
# Description_VINTAGE KITCHEN PRINT PUDDINGS            0
# Description_VINTAGE KITCHEN PRINT VEGETABLES          0
# Description_VINTAGE LEAF MAGNETIC NOTEPAD             0
# Description_VINTAGE NOTEBOOK BEAUTY GIRL              0
# Description_VINTAGE NOTEBOOK PARIS DAYS               0
# Description_VINTAGE PAISLEY STATIONERY SET            0
# Description_VINTAGE POST OFFICE CABINET               0
# Description_VINTAGE RED ENAMEL TRIM JUG               0
# Description_VINTAGE RED ENAMEL TRIM MUG               0
# Description_VINTAGE RED ENAMEL TRIM PLATE             0
# Description_VINTAGE RED TEATIME MUG                   0
# Description_VINTAGE RED TRIM ENAMEL BOWL              0
# Description_VINTAGE ROSE BEAD BRACELET BLACK          0
# Description_VINTAGE ROSE BEAD BRACELET RASPBERR       0
# Description_VINTAGE SEASIDE JIGSAW PUZZLES            0
# Description_VINTAGE SHELLS PRINT                      0
# Description_VINTAGE SNAKES & LADDERS                  0
# Description_VINTAGE SNAP CARDS                        0
# Description_VINTAGE UNION JACK APRON                  0
# Description_VINTAGE UNION JACK BUNTING                0
# Description_VINTAGE UNION JACK CUSHION COVER          0
# Description_VINTAGE UNION JACK DOORSTOP               0
# Description_VINTAGE UNION JACK MEMOBOARD              0
# Description_VINTAGE UNION JACK PENNANT                0
# Description_VINTAGE UNION JACK SHOPPING BAG           0
# Description_VINYL RECORD FRAME SILVER                 0
# Description_VIPPASSPORT COVER                         0
# Description_WAKE UP COCKEREL CALENDAR SIGN            0
# Description_WAKE UP COCKEREL TILE COASTER             0
# Description_WAKE UP COCKEREL TILE HOOK                0
# Description_WALL ART BICYCLE SAFETY                   0
# Description_WALL ART BIG LOVE                         0
# Description_WALL ART CLASSIC PUDDINGS                 0
# Description_WALL ART DOG LICENCE                      0
# Description_WALL ART KEEP CALM                        0
# Description_WALL ART ONLY ONE PERSON                  0
# Description_WALL ART STOP FOR TEA                     0
# Description_WALL ART VILLAGE SHOW                     0
# Description_WALL ART VINTAGE HEART                    0
# Description_WALL MIRROR , DIAMANTE OVAL SHAPE         0
# Description_WALL MIRROR , RECT DIAMANTE, PINK/        0
# Description_WALL MIRROR RECTANGLE DIAMANTE PINK       0
# Description_WALL MOUNTED VINTAGE ORGANISER            0
# Description_WALL TIDY RETROSPOT                       0
# Description_WASH BAG VINTAGE ROSE PAISLEY             0
# Description_WASHROOM METAL SIGN                       0
# Description_WATERING CAN BLUE ELEPHANT                0
# Description_WATERING CAN GREEN DINOSAUR               0
# Description_WATERING CAN PINK BUNNY                   0
# Description_WATERING CAN SINGLE HOOK PISTACHIO        0
# Description_WATERMELON BATH SPONGE                    0
# Description_WAY OUT METAL SIGN                        0
# Description_WEEKEND BAG VINTAGE ROSE PAISLEY          0
# Description_WELCOME  WOODEN BLOCK LETTERS             0
# Description_WHEELBARROW FOR CHILDREN                  0
# Description_WHITE ADVENT CANDLE                       0
# Description_WHITE AND BLUE CERAMIC OIL BURNER         0
# Description_WHITE BAMBOO RIBS LAMPSHADE               0
# Description_WHITE BAROQUE WALL CLOCK                  0
# Description_WHITE BELL HONEYCOMB PAPER                0
# Description_WHITE BELL HONEYCOMB PAPER GARLAND        0
# Description_WHITE BROCANTE SOAP DISH                  0
# Description_WHITE CERAMIC PARTY SET (5PCS)            0
# Description_WHITE CHERRY LIGHTS                       0
# Description_WOODEN HAPPY BIRTHDAY GARLAND             0
# Description_WOODEN HEART CHRISTMAS SCANDINAVIAN       0
# Description_WOODEN OWLS LIGHT GARLAND                 0
# Description_WOODEN PICTURE FRAME WHITE FINISH         0
# Description_WOODEN REGATTA BUNTING                    0
# Description_WOODEN ROUNDERS GARDEN SET                0
# Description_WOODEN SCHOOL COLOURING SET               0
# Description_WOODEN STAR CHRISTMAS SCANDINAVIAN        0
# Description_WOODEN TREE CHRISTMAS SCANDINAVIAN        0
# Description_WOODEN UNION JACK BUNTING                 0
# Description_WOODLAND  HEIGHT CHART STICKERS           0
# Description_WOODLAND  STICKERS                        0
# Description_WOODLAND ANIMAL  WRITING SET              0
# Description_WOODLAND BUNNIES LOLLY MAKERS             0
# Description_WOODLAND CHARLOTTE BAG                    0
# Description_WOODLAND DESIGN  COTTON TOTE BAG          0
# Description_WOODLAND MINI BACKPACK                    0
# Description_WOODLAND PARTY BAG + STICKER SET          0
# Description_WOODLAND SMALL PINK FELT HEART            0
# Description_WOODLAND STORAGE BOX LARGE                0
# Description_WOODLAND STORAGE BOX SMALL                0
# Description_WOODLAND WATER TRANSFER TATTOOS           0
# Description_WORLD WAR 2 GLIDERS ASSTD DESIGNS         0
# Description_WOVEN BERRIES CUSHION COVER               0
# Description_WOVEN BUBBLE GUM CUSHION COVER            0
# Description_WOVEN FROST CUSHION COVER                 0
# Description_WOVEN ROSE GARDEN CUSHION COVER           0
# Description_WOVEN SUNSET CUSHION COVER                0
# Description_WRAP  PINK FLOCK                          0
# Description_WRAP 50'S  CHRISTMAS                      0
# Description_WRAP ALPHABET DESIGN                      0
# Description_WRAP BIRD GARDEN                          0
# Description_WRAP BLUE REINDEER                        0
# Description_WRAP BOUDOIR                              0
# Description_WRAP CHRISTMAS SCREEN PRINT               0
# Description_WRAP CHRISTMAS VILLAGE                    0
# Description_WRAP COWBOYS                              0
# Description_WRAP DOILEY DESIGN                        0
# Description_WRAP DOLLY GIRL                           0
# Description_WRAP ENGLISH ROSE                         0
# Description_WRAP GINGHAM ROSE                         0
# Description_WRAP GREEN RUSSIAN FOLKART                0
# Description_WRAP I LOVE LONDON                        0
# Description_WRAP MAGIC FOREST                         0
# Description_WRAP PAISLEY PARK                         0
# Description_WRAP PINK FAIRY CAKES                     0
# Description_WRAP RED APPLES                           0
# Description_WRAP RED VINTAGE DOILY                    0
# Description_WRAP WEDDING DAY                          0
# Description_WRAP, FRIENDSHIP ON GREEN                 0
# Description_WRAP,SUKI AND FRIENDS                     0
# Description_YELLOW BREAKFAST CUP AND SAUCER           0
# Description_YELLOW COAT RACK PARIS FASHION            0
# Description_YELLOW EASTER EGG HUNT START POST         0
# Description_YELLOW SHARK HELICOPTER                   0
# Description_YOU'RE CONFUSING ME METAL SIGN            0
# Description_ZINC FINISH 15CM PLANTER POTS             0
# Description_ZINC FOLKART SLEIGH BELLS                 0
# Description_ZINC HEART LATTICE CHARGER LARGE          0
# Description_ZINC HEART LATTICE PLANTER BOWL           0
# Description_ZINC HEART LATTICE T-LIGHT HOLDER         0
# Description_ZINC HERB GARDEN CONTAINER                0
# Description_ZINC METAL HEART DECORATION               0
# Description_ZINC SWEETHEART WIRE LETTER RACK          0
# Description_ZINC T-LIGHT HOLDER STARS SMALL           0
# Description_ZINC WILLIE WINKIE  CANDLE STICK          0
# Description_ZINC WIRE SWEETHEART LETTER TRAY          0
# Description_damaged                                   0
# Description_damages                                   0
# Description_dirty, torn, thrown away.                 0
# Description_water damage                              0
# dtype: int64

# %%
data_encoded.head()
# Out:
#        Invoice StockCode  Quantity         InvoiceDate  Price  Customer ID  \
# 455941  532657       NaN        12 2010-11-14 11:10:00   2.10      14562.0
# 300830  563214       NaN         2 2011-08-14 12:56:00   1.65      16370.0
# 191636  507597       NaN        12 2010-05-10 13:21:00   1.65      17700.0
# 25864   491634       NaN         1 2009-12-11 15:40:00   2.55      17841.0
# 73233   496007     85232         3 2010-01-28 12:32:00   4.95      15203.0
#
#         Country_Australia  Country_Austria  Country_Bahrain  Country_Belgium  \
# 455941                  0                0                0                0
# 300830                  0                0                0                0
# 191636                  0                0                0                0
# 25864                   0                0                0                0
# 73233                   0                0                0                0
#
#         ...  Description_ZINC HERB GARDEN CONTAINER  \
# 455941  ...                                       0
# 300830  ...                                       0
# 191636  ...                                       0
# 25864   ...                                       0
# 73233   ...                                       0
#
#         Description_ZINC METAL HEART DECORATION  \
# 455941                                        0
# 300830                                        0
# 191636                                        0
# 25864                                         0
# 73233                                         0
#
#         Description_ZINC SWEETHEART WIRE LETTER RACK  \
# 455941                                             0
# 300830                                             0
# 191636                                             0
# 25864                                              0
# 73233                                              0
#
#         Description_ZINC T-LIGHT HOLDER STARS SMALL  \
# 455941                                            0
# 300830                                            0
# 191636                                            0
# 25864                                             0
# 73233                                             0
#
#         Description_ZINC WILLIE WINKIE  CANDLE STICK  \
# 455941                                             0
# 300830                                             0
# 191636                                             0
# 25864                                              0
# 73233                                              0
#
#         Description_ZINC WIRE SWEETHEART LETTER TRAY  Description_damaged  \
# 455941                                             0                    0
# 300830                                             0                    0
# 191636                                             0                    0
# 25864                                              0                    0
# 73233                                              0                    0
#
#         Description_damages  Description_dirty, torn, thrown away.  \
# 455941                    0                                      0
# 300830                    0                                      0
# 191636                    0                                      0
# 25864                     0                                      0
# 73233                     0                                      0
#
#         Description_water damage
# 455941                         0
# 300830                         0
# 191636                         0
# 25864                          0
# 73233                          0
#
# [5 rows x 2912 columns]

# %%
scaler = StandardScaler()
data_scaled = scaler.fit_transform(data_encoded)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[62], line 2
#       1 scaler = StandardScaler()
# ----> 2 data_scaled = scaler.fit_transform(data_encoded)
#
# File ~/Documents/anaconda3/lib/python3.11/site-packages/sklearn/utils/_set_output.py:157, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     155 @wraps(f)
#     156 def wrapped(self, X, *args, **kwargs):
# --> 157     data_to_wrap = f(self, X, *args, **kwargs)
#     158     if isinstance(data_to_wrap, tuple):
#     159         # only wrap the first output for cross decomposition
#     160         return_tuple = (
#     161             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     162             *data_to_wrap[1:],
#     163         )
#
# File ~/Documents/anaconda3/lib/python3.11/site-packages/sklearn/base.py:916, in TransformerMixin.fit_transform(self, X, y, **fit_params)
#     912 # non-optimized default implementation; override when a better
#     913 # method is possible for a given clustering algorithm
#     914 if y is None:
#     915     # fit method of arity 1 (unsupervised transformation)
# --> 916     return self.fit(X, **fit_params).transform(X)
#     917 else:
#     918     # fit method of arity 2 (supervised transformation)
#     919     return self.fit(X, y, **fit_params).transform(X)
#
# File ~/Documents/anaconda3/lib/python3.11/site-packages/sklearn/preprocessing/_data.py:839, in StandardScaler.fit(self, X, y, sample_weight)
#     837 # Reset internal state before fitting
#     838 self._reset()
# --> 839 return self.partial_fit(X, y, sample_weight)
#
# File ~/Documents/anaconda3/lib/python3.11/site-packages/sklearn/base.py:1152, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1145     estimator._validate_params()
#    1147 with config_context(
#    1148     skip_parameter_validation=(
#    1149         prefer_skip_nested_validation or global_skip_validation
#    1150     )
#    1151 ):
# -> 1152     return fit_method(estimator, *args, **kwargs)
#
# File ~/Documents/anaconda3/lib/python3.11/site-packages/sklearn/preprocessing/_data.py:875, in StandardScaler.partial_fit(self, X, y, sample_weight)
#     843 """Online computation of mean and std on X for later scaling.
#     844
#     845 All of X is processed as a single batch. This is intended for cases
#    (...)
#     872     Fitted scaler.
#     873 """
#     874 first_call = not hasattr(self, "n_samples_seen_")
# --> 875 X = self._validate_data(
#     876     X,
#     877     accept_sparse=("csr", "csc"),
#     878     dtype=FLOAT_DTYPES,
#     879     force_all_finite="allow-nan",
#     880     reset=first_call,
#     881 )
#     882 n_features = X.shape[1]
#     884 if sample_weight is not None:
#
# File ~/Documents/anaconda3/lib/python3.11/site-packages/sklearn/base.py:605, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, cast_to_ndarray, **check_params)
#     603         out = X, y
#     604 elif not no_val_X and no_val_y:
# --> 605     out = check_array(X, input_name="X", **check_params)
#     606 elif no_val_X and not no_val_y:
#     607     out = _check_y(y, **check_params)
#
# File ~/Documents/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:915, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#     913         array = xp.astype(array, dtype, copy=False)
#     914     else:
# --> 915         array = _asarray_with_order(array, order=order, dtype=dtype, xp=xp)
#     916 except ComplexWarning as complex_warning:
#     917     raise ValueError(
#     918         "Complex data not supported\n{}\n".format(array)
#     919     ) from complex_warning
#
# File ~/Documents/anaconda3/lib/python3.11/site-packages/sklearn/utils/_array_api.py:380, in _asarray_with_order(array, dtype, order, copy, xp)
#     378     array = numpy.array(array, order=order, dtype=dtype)
#     379 else:
# --> 380     array = numpy.asarray(array, order=order, dtype=dtype)
#     382 # At this point array is a NumPy ndarray. We convert it to an array
#     383 # container that is consistent with the input's namespace.
#     384 return xp.asarray(array)
#
# File ~/Documents/anaconda3/lib/python3.11/site-packages/pandas/core/generic.py:2070, in NDFrame.__array__(self, dtype)
#    2069 def __array__(self, dtype: npt.DTypeLike | None = None) -> np.ndarray:
# -> 2070     return np.asarray(self._values, dtype=dtype)
#
# ValueError: could not convert string to float: 'C552212'

# %%
scaler = StandardScaler()
data_scaled = scaler.fit_transform(data_encoded[['Quantity', 'Customer ID', 'Price']])

# %%
kmeans = KMeans(n_clusters=5, random_state=42)

# %%
kmeans_clusters = kmeans.fit_predict(data_scaled)

# %%
wcss = []
for k in range(2, 10):
    kmeans = KMeans(n_clusters=k, n_init=10, random_state=42)
    kmeans.fit(data_scaled)
    wcss.append(kmeans.inertia_)
print(wcss)
# Out:
# [22505.043613190886, 15392.759197188805, 10215.869713709282, 7423.06615789374, 5870.732755344878, 4473.6976882107065, 3800.4568231079325, 3017.891695943485]

# %%
plt.plot(range(2,10), wcss);

# %%
kmeans_silhouette = silhouette_score(data_scaled, kmeans_clusters)
print("Silhouette Score for KMeans:", kmeans_silhouette)
# Out:
# Silhouette Score for KMeans: 0.5575654395443425

# %%
plt.scatter(data_scaled[:, 0], data_scaled[:, 1], c=kmeans_clusters, cmap='viridis', s=50, edgecolors='k')
plt.title('KMeans Clustering')
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.show()

# %%
plt.figure(figsize=(12, 6))
plt.subplot(1, 3, 1)
plt.scatter(data_scaled[:, 0], data_scaled[:, 1], c=kmeans_clusters, cmap='viridis')
plt.title(f'K-Means (Silhouette Score: {kmeans_silhouette:.2f})')
plt.xlabel('Quantity (Scaled)')
plt.ylabel('Price (Scaled)')
plt.tight_layout()
plt.show()

# %%
from sklearn.cluster import DBSCAN

# %%
dbscan = DBSCAN(eps=0.5, min_samples=5)
dbscan_clusters = dbscan.fit_predict(data_scaled)

# %%
plt.subplot(1, 3, 2)
plt.scatter(data_scaled[:, 0], data_scaled[:, 1], c=dbscan_clusters, cmap='viridis')
plt.title('DBSCAN')
plt.xlabel('Quantity (Scaled)')
plt.ylabel('Price (Scaled)')
plt.tight_layout()
plt.show()

# %%
dfvdfd

# %%
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.cluster import KMeans, DBSCAN, AgglomerativeClustering

# %%
data_encoded = pd.get_dummies(data_df, columns=['Country', 'Description'])

# %%
scaler = StandardScaler()
data_scaled = scaler.fit_transform(data_encoded[['Quantity', 'Price']])

# %%
data_scaled
# Out:
# array([[ 0.01193418,  0.01862045],
#        [ 0.01193418,  0.01700171],
#        [ 0.01193418,  0.01700171],
#        ...,
#        [-0.03438739, -0.00404189],
#        [-0.04017759,  0.00243306],
#        [-0.05175798,  0.10805575]])

# %%
wcss = []
for k in range(2, 10):
    kmeans = KMeans(n_clusters=k, n_init=10, random_state=42)
    kmeans.fit(data_scaled)
    wcss.append(kmeans.inertia_)
print(wcss)
# Out:
# [1712843.652017807, 1305607.2317412978, 901675.4279049414, 497952.02533215075, 396475.32886527444, 304456.1484608431, 250356.66161654954, 200815.70478092667]

# %%
plt.plot(range(2,10), wcss);

# %%
kmeans = KMeans(n_clusters=3, n_init=10, random_state=42)

# %%
data_scaled.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 data_scaled.head()
#
# AttributeError: 'numpy.ndarray' object has no attribute 'head'

# %%
kmeans.cluster_centers_
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 kmeans.cluster_centers_
#
# AttributeError: 'KMeans' object has no attribute 'cluster_centers_'

# %%
kmeans.fit(data_scaled)
# Out:
# KMeans(n_clusters=3, n_init=10, random_state=42)

# %% [markdown]
# kmeans_silhouette = silhouette_score(data_scaled, kmeans_clusters)

# %%
plt.figure(figsize=(12, 6))
plt.subplot(1, 3, 1)
plt.scatter(data_scaled[:, 0], data_scaled[:, 1], c=kmeans_clusters, cmap='viridis')
plt.title(f'K-Means (Silhouette Score: {kmeans_silhouette:.2f})')
plt.xlabel('Quantity (Scaled)')
plt.ylabel('Price (Scaled)')
plt.tight_layout()
plt.show()

# %% [markdown]
# Label encoder to be used to transform Country from a categorical feature into a numerical feature to be able to use it in clustering.

# %%
from sklearn.preprocessing import LabelEncoder

# %%
label = LabelEncoder()

# %%
data_df['New Country']=label.fit_transform(data_df['Country'])

# %%
data_df.drop(['Country'],axis=1,inplace=True)

# %%
data_df.head(100)
# Out:
#    Invoice StockCode                          Description  Quantity  \
# 0   489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1   489434    79323P                   PINK CHERRY LIGHTS        12
# 2   489434    79323W                  WHITE CHERRY LIGHTS        12
# 3   489434     22041         RECORD FRAME 7" SINGLE SIZE         48
# 4   489434     21232       STRAWBERRY CERAMIC TRINKET BOX        24
# 5   489434     22064           PINK DOUGHNUT TRINKET POT         24
# 6   489434     21871                  SAVE THE PLANET MUG        24
# 7   489434     21523   FANCY FONT HOME SWEET HOME DOORMAT        10
# 8   489435     22350                            CAT BOWL         12
# 9   489435     22349       DOG BOWL , CHASING BALL DESIGN        12
# 10  489435     22195         HEART MEASURING SPOONS LARGE        24
# 11  489435     22353   LUNCHBOX WITH CUTLERY FAIRY CAKES         12
# 12  489436    48173C                DOOR MAT BLACK FLOCK         10
# 13  489436     21755             LOVE BUILDING BLOCK WORD        18
# 14  489436     21754             HOME BUILDING BLOCK WORD         3
# 15  489436     84879        ASSORTED COLOUR BIRD ORNAMENT        16
# 16  489436     22119           PEACE WOODEN BLOCK LETTERS         3
# 17  489436     22142         CHRISTMAS CRAFT WHITE FAIRY         12
# 18  489436     22296            HEART IVORY TRELLIS LARGE        12
# 19  489436     22295            HEART FILIGREE DOVE LARGE        12
# 20  489436     22109         FULL ENGLISH BREAKFAST PLATE        16
# 21  489436     22107                   PIZZA PLATE IN BOX         4
# 22  489436     22194               BLACK DINER WALL CLOCK         2
# 23  489436    35004B          SET OF 3 BLACK FLYING DUCKS        12
# 24  489436     82582            AREA PATROLLED METAL SIGN        12
# 25  489436     21181        PLEASE ONE PERSON  METAL SIGN        12
# 26  489436     21756             BATH BUILDING BLOCK WORD         3
# 27  489436     21333                  CLASSIC WHITE FRAME         6
# 28  489436    84596F         SMALL MARSHMALLOWS PINK BOWL         8
# 29  489436    84596L       BISCUITS SMALL BOWL LIGHT BLUE         8
# 30  489436     22111         SCOTTIE DOG HOT WATER BOTTLE        24
# 31  489437     22143    CHRISTMAS CRAFT HEART DECORATIONS         6
# 32  489437     22145      CHRISTMAS CRAFT HEART STOCKING          6
# 33  489437     22130     PARTY CONE CHRISTMAS DECORATION         12
# 34  489437     21364             PEACE SMALL WOOD LETTERS         2
# 35  489437     21360               JOY LARGE WOOD LETTERS         1
# 36  489437     21351             CINAMMON & ORANGE WREATH         2
# 37  489437     21352        EUCALYPTUS & PINECONE  WREATH         2
# 38  489437     35400          WOODEN BOX ADVENT CALENDAR          2
# 39  489437     20695                  FLORAL BLUE MONSTER         3
# 40  489437     37370           RETRO COFFEE MUGS ASSORTED        12
# 41  489437     10002          INFLATABLE POLITICAL GLOBE         12
# 42  489437    84507B           STRIPES DESIGN MONKEY DOLL         6
# 43  489437     20703              BLUE PADDED SOFT MOBILE         3
# 44  489437     21987           PACK OF 6 SKULL PAPER CUPS        12
# 45  489437     21989       PACK OF 20 SKULL PAPER NAPKINS        12
# 46  489437    84970S    HANGING HEART ZINC T-LIGHT HOLDER        12
# 47  489437     20971     PINK BLUE FELT CRAFT TRINKET BOX        12
# 48  489437     22271                 FELTCRAFT DOLL ROSIE         6
# 49  489437     22272                 FELTCRAFT DOLL MARIA         6
# 50  489437     22274                 FELTCRAFT DOLL EMILY         6
# 51  489437     21912             VINTAGE SNAKES & LADDERS         4
# 52  489437     22111         SCOTTIE DOG HOT WATER BOTTLE         3
# 53  489437     22112           CHOCOLATE HOT WATER BOTTLE         3
# 54  489438     21329              DINOSAURS  WRITING SET         28
# 55  489438     21252       SET OF MEADOW  FLOWER STICKERS        30
# 56  489438     21100       CHARLIE AND LOLA CHARLOTTE BAG        30
# 57  489438     21033      JUMBO BAG CHARLIE AND LOLA TOYS        30
# 58  489438     20711                      JUMBO BAG TOYS         60
# 59  489438     21410      COUNTRY COTTAGE  DOORSTOP GREEN        32
# 60  489438     21411          GINGHAM HEART  DOORSTOP RED        32
# 61  489438    84031A   CHARLIE+LOLA RED HOT WATER BOTTLE         56
# 62  489438    84031B  CHARLIE LOLA BLUE HOT WATER BOTTLE         56
# 63  489438    84032A   CHARLIE+LOLA PINK HOT WATER BOTTLE        60
# 64  489438    84032B  CHARLIE + LOLA RED HOT WATER BOTTLE        56
# 65  489438    84519A      TOMATO CHARLIE+LOLA COASTER SET        56
# 66  489438    84519B      CARROT CHARLIE+LOLA COASTER SET        60
# 67  489438    85132A         CHARLIE + LOLA BISCUITS TINS        60
# 68  489438    85132C        CHARLIE AND LOLA FIGURES TINS        60
# 69  489438    85183A   CHARLIE & LOLA WASTEPAPER BIN BLUE        60
# 70  489438    85183B  CHARLIE & LOLA WASTEPAPER BIN FLORA        60
# 71  489439     22065       CHRISTMAS PUDDING TRINKET POT         12
# 72  489439     22138        BAKING SET 9 PIECE RETROSPOT          9
# 73  489439     22139    RETRO SPOT TEA SET CERAMIC 11 PC          9
# 74  489439     22352     LUNCHBOX WITH CUTLERY RETROSPOT         12
# 75  489439    85014A     BLACK/BLUE DOTS RUFFLED UMBRELLA         3
# 76  489439    85014B      RED/WHITE DOTS RUFFLED UMBRELLA         3
# 77  489439    16161P                   WRAP ENGLISH ROSE         25
# 78  489439    16169N            WRAP BLUE RUSSIAN FOLKART        25
# 79  489439     21491      SET OF THREE VINTAGE GIFT WRAPS         6
# 80  489439     22333  RETRO SPORT PARTY BAG + STICKER SET         8
# 81  489439     85216        ASSORTED CAKES FRIDGE MAGNETS        12
# 82  489439     21493             VINTAGE DESIGN GIFT TAGS        12
# 83  489439     22130     PARTY CONE CHRISTMAS DECORATION         24
# 84  489439     22064           PINK DOUGHNUT TRINKET POT         12
# 85  489439     21731        RED TOADSTOOL LED NIGHT LIGHT        24
# 86  489439    85232B     SET/3 RUSSIAN DOLL STACKING TINS         6
# 87  489439     84691                   PACK 20 DOLLY PEGS        12
# 88  489439     20749           ASSORTED COLOUR MINI CASES         2
# 89  489439      POST                              POSTAGE         3
# 90  489440     22350                            CAT BOWL          8
# 91  489440     22349       DOG BOWL , CHASING BALL DESIGN         8
# 92  489441     22321             BIRD DECORATION RED SPOT        12
# 93  489441     22138        BAKING SET 9 PIECE RETROSPOT          6
# 94  489441    84029E       RED WOOLLY HOTTIE WHITE HEART.        36
# 95  489441     22111         SCOTTIE DOG HOT WATER BOTTLE        48
# 96  489442     21955     UNION JACK GUNS & ROSES  DOORMAT         2
# 97  489442     22111         SCOTTIE DOG HOT WATER BOTTLE         3
#
# %%
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
sns.histplot(data=new_data, x='Quantity', bins=20, kde=True)
plt.title('Distribution of Quantity')

plt.subplot(1, 2, 2)
sns.histplot(data=new_data, x='Price', bins=20, kde=True)
plt.title('Distribution of Price')

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.scatterplot(data=new_data, x='Quantity', y='Price')
plt.title('Scatter Plot of Quantity vs. Price')
plt.xlabel('Quantity')
plt.ylabel('Price')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(data=new_data[['Quantity', 'Price']])
plt.title('Box Plot of Quantity and Price')
plt.ylabel('Value')
plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.countplot(data=new_data, x='New Country', order=new_data['New Country'].value_counts().index)
plt.title('Bar Plot of New Country')
plt.xticks(rotation=45)
plt.xlabel('Country')
plt.ylabel('Count')
plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.violinplot(data=new_data, x='New Country', y='Quantity')
plt.title('Violin Plot of Quantity by New Country')
plt.xticks(rotation=45)
plt.xlabel('Country')
plt.ylabel('Quantity')
plt.show()

# %% [markdown]
# sns.kdeplot(new_df['New Country'], shade=True,hue=new_data['Quantity']);

# %% [markdown]
# for i in columns:
#     plt.figure()
#     sns.displot(columns[i])

# %% [markdown]
# Using standard scaler to improve the performance of algorithms.

# %%
scaler = StandardScaler()
scaled = scaler.fit_transform(new_data)

# %%
new_data.head()
# Out:
#    Quantity  Price  New Country
# 0        12   6.95           40
# 1        12   6.75           40
# 2        12   6.75           40
# 3        48   2.10           40
# 4        24   1.25           40

# %%
clustering1 = KMeans(n_clusters=2)

# %%
clustering1.fit(new_data[['New Country']])
# Out:
# KMeans(n_clusters=2)

# %%
clustering1.labels_
# Out:
# array([0, 0, 0, ..., 1, 1, 1], dtype=int32)

# %%
new_data['Country Cluster']=clustering1.labels_
new_data.head()
# Out:
#    Quantity  Price  New Country  Country Cluster  Country Cluster and Quantity
# 0        12   6.95           40                0                             0
# 1        12   6.75           40                0                             0
# 2        12   6.75           40                0                             0
# 3        48   2.10           40                0                             0
# 4        24   1.25           40                0                             0

# %%
new_data['Country Cluster'].value_counts()
# Out:
# 0    996782
# 1     70589
# Name: Country Cluster, dtype: int64

# %%
clustering1.inertia_
# Out:
# 2933150.6298677586

# %%
wcss = []
for k in range(1, 10):
    kmeans = KMeans(n_clusters=k, n_init=10, random_state=42)
    kmeans.fit(new_data[['New Country']])
    wcss.append(kmeans.inertia_)
print(wcss)
# Out:
# [49646669.4101205, 2933150.6298677586, 1383851.7300109076, 618755.4532765154, 391677.6004536674, 187985.42918188832, 113645.17506672796, 78699.12499909542, 48177.59462083066]

# %%
plt.plot(range(1,10), wcss);

# %%
new_data.groupby('Country Cluster')['Quantity', 
       'Price', 'New Country'].mean()
# Out:
#                   Quantity     Price  New Country
# Country Cluster
# 0                 8.859475  4.537358    39.999282
# 1                27.704682  6.638118    10.491071
# 2                42.736080  8.229278    27.398580
# 3                24.538259  4.476589     1.941295
# 4                13.449388  4.767302    14.955616
# 5                22.171783  7.620822    34.864484

# %%
clustering2 = KMeans(n_clusters=3)
clustering2.fit(new_data[['New Country','Quantity']])
new_data['Country Cluster and Quantity'] = clustering2.labels_
new_data.head()
# Out:
#    Quantity  Price  New Country  Country Cluster  Country Cluster and Quantity
# 0        12   6.95           40                0                             0
# 1        12   6.75           40                0                             0
# 2        12   6.75           40                0                             0
# 3        48   2.10           40                0                             0
# 4        24   1.25           40                0                             0

# %%
wcss1 = []
for k in range(1, 10):
    kmeans1 = KMeans(n_clusters=k, n_init=10, random_state=42)
    kmeans1.fit(new_data[['New Country','Quantity']])
    wcss1.append(kmeans1.inertia_)
print(wcss1)
# Out:
# [31886402592.49911, 19838222529.738983, 7796258083.553131, 4769479604.6533785, 3159112366.5349207, 2330721917.016167, 1684680049.549134, 1364248841.7050478, 1065401114.377281]

# %%
plt.plot(range(1,10), wcss1);

# %%
sns.scatterplot(data=new_data, x='New Country', y='Quantity',hue='Country Cluster and Quantity')
# Out:
# <Axes: xlabel='New Country', ylabel='Quantity'>

# %%
center = pd.DataFrame(clustering2.cluster_centers_)
center.columns = ['X', 'Y']

# %%
plt.figure(figsize=(10,8))
plt.scatter(x=center['X'],y=center['Y'],s=100,c='black',marker='*')

sns.scatterplot(data=new_data, x='New Country', y='Quantity',hue='Country Cluster and Quantity')
# Out:
# <Axes: xlabel='New Country', ylabel='Quantity'>

# %%
kmeans = KMeans(n_clusters=6, n_init=10, random_state=42)
kmeans.fit_predict('Quantity')

# %%
wcss = []
for k in range(0, 10):
    kmeans = KMeans(n_clusters=k, n_init=10, random_state=42)
    kmeans.fit(new_data)
    wcss.append(kmeans.inertia_)
print(wcss)

# %%
plt.plot(range(2,10), wcss);

# %%
new_data['Country Cluster'] = kmeans.labels_
new_data.head(100)

# %%
def plotFeatures(col1, col2):
    plt.scatter(
        new_data[kmeans.labels_ == 0].iloc[:, col1],
        new_data[kmeans.labels_ == 0].iloc[:, col2],
        s=50,
        c='red',
        label='Cluster 1'
    )
    plt.scatter(
        new_data[kmeans.labels_ == 1].iloc[:, col1],
        new_data[kmeans.labels_ == 1].iloc[:, col2],
        s=50,
        c='blue',
        label='Cluster 2'
    )
    plt.scatter(
        new_data[kmeans.labels_ == 2].iloc[:, col1],
        new_data[kmeans.labels_ == 2].iloc[:, col2],
        s=50,
        c='green',
        label='Cluster 3'
    )
    plt.scatter(
        kmeans.cluster_centers_[:, col1],
        kmeans.cluster_centers_[:, col2],
        s=100,
        c='yellow',
        label='Centroids'
    )
    plt.xlabel(new_data.columns[col1])
    plt.ylabel(new_data.columns[col2])
    plt.legend()
    plt.title('Clustering based on ' + new_data.columns[col1] + ' and ' + new_data.columns[col2])
    plt.show()

plotFeatures(0, 1)

# %%
plotFeatures(0,2)

# %%
plotFeatures(1,2)

# %% [markdown]
# kmeans = KMeans(n_clusters=3,n_init=10,random_state=42)

# %% [markdown]
# y_pred = kmeans.fit_predict(x)

# %% [markdown]
# y_pred

# %% [markdown]
# wcss = []
# for k in range(2,10):
#     kmeans = KMeans(n_clusters=k,n_init=10,random_state=42)
#     kmeans.fit(x)
#     wcss.append(kmeans.inertia_)
# print(wcss)

# %% [markdown]
# plt.plot(range(2,10),wcss);

# %% [markdown]
# silhouette_score(x,y_pred)

# %%
clustering1 = KMeans()

# %%
clustering1.fit(new_data[['New Country']])

# %%
clustering1.labels_
#for label in clustering1.labels_:
    #print(label)

# %%
new_data['Country Cluster'].value_counts()

# %%
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
from sklearn_extra.cluster import KMedoids

# %%
df = data_df[['Quantity','Price']]

# %%
df.head()

# %%
standard = StandardScaler()

# %%
x = standard.fit_transform(df)

# %%
coumns = df.columns

# %%
coumns

# %%
df = pd.DataFrame(standard.fit_transform(df),columns=coumns)

# %%
df.head()

# %% [markdown]
# K-elbow method

# %%
wcss = []
for k in range (2,10):
    kmeans = KMeans(n_clusters = k,random_state=42)
    kmeans.fit(x)
    wcss.append(kmeans.inertia_)
plt.plot(range(2,10),wcss);

# %% [markdown]
# Silhouette Score

# %% [markdown]
# wcss = []
# for k in range (2,10):
#     kmeans = KMeans(n_clusters = k,random_state=42)
#     y_kmeans = kmeans.fit_predict(df)
#     wcss.append(silhouette_score(df,y_kmeans))
# plt.plot(range(2,10),wcss);
