# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import LabelEncoder

from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import silhouette_score

import warnings
warnings.filterwarnings('ignore')

# %%
d1 = pd.read_excel('data.xlsx',0)

# %%
d1.head()
# Out:
#   Invoice StockCode                          Description  Quantity  \
# 0  489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1  489434    79323P                   PINK CHERRY LIGHTS        12
# 2  489434    79323W                  WHITE CHERRY LIGHTS        12
# 3  489434     22041         RECORD FRAME 7" SINGLE SIZE         48
# 4  489434     21232       STRAWBERRY CERAMIC TRINKET BOX        24
#
#           InvoiceDate  Price  Customer ID         Country
# 0 2009-12-01 07:45:00   6.95      13085.0  United Kingdom
# 1 2009-12-01 07:45:00   6.75      13085.0  United Kingdom
# 2 2009-12-01 07:45:00   6.75      13085.0  United Kingdom
# 3 2009-12-01 07:45:00   2.10      13085.0  United Kingdom
# 4 2009-12-01 07:45:00   1.25      13085.0  United Kingdom

# %%
d2 = pd.read_excel('data.xlsx',1)

# %%
d2.head()
# Out:
#   Invoice StockCode                          Description  Quantity  \
# 0  536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1  536365     71053                  WHITE METAL LANTERN         6
# 2  536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3  536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4  536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  Price  Customer ID         Country
# 0 2010-12-01 08:26:00   2.55      17850.0  United Kingdom
# 1 2010-12-01 08:26:00   3.39      17850.0  United Kingdom
# 2 2010-12-01 08:26:00   2.75      17850.0  United Kingdom
# 3 2010-12-01 08:26:00   3.39      17850.0  United Kingdom
# 4 2010-12-01 08:26:00   3.39      17850.0  United Kingdom

# %%
data_df = pd.concat([d1,d2])

# %%
pd.set_option('display.max_rows', None)
data_df.head(100)
# Out:
#    Invoice StockCode                          Description  Quantity  \
# 0   489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1   489434    79323P                   PINK CHERRY LIGHTS        12
# 2   489434    79323W                  WHITE CHERRY LIGHTS        12
# 3   489434     22041         RECORD FRAME 7" SINGLE SIZE         48
# 4   489434     21232       STRAWBERRY CERAMIC TRINKET BOX        24
# 5   489434     22064           PINK DOUGHNUT TRINKET POT         24
# 6   489434     21871                  SAVE THE PLANET MUG        24
# 7   489434     21523   FANCY FONT HOME SWEET HOME DOORMAT        10
# 8   489435     22350                            CAT BOWL         12
# 9   489435     22349       DOG BOWL , CHASING BALL DESIGN        12
# 10  489435     22195         HEART MEASURING SPOONS LARGE        24
# 11  489435     22353   LUNCHBOX WITH CUTLERY FAIRY CAKES         12
# 12  489436    48173C                DOOR MAT BLACK FLOCK         10
# ...

# %%
data_df.shape
# Out:
# (1067371, 8)

# %%
data_df.describe()
# Out:
#            Quantity         Price    Customer ID
# count  1.067371e+06  1.067371e+06  824364.000000
# mean   9.938898e+00  4.649388e+00   15324.638504
# std    1.727058e+02  1.235531e+02    1697.464450
# min   -8.099500e+04 -5.359436e+04   12346.000000
# 25%    1.000000e+00  1.250000e+00   13975.000000
# 50%    3.000000e+00  2.100000e+00   15255.000000
# 75%    1.000000e+01  4.150000e+00   16797.000000
# max    8.099500e+04  3.897000e+04   18287.000000

# %%
features = ['Quantity', 'Price']

# %% [markdown]
# plt.figure(figsize=(10, 6))
# plt.scatter(features, price, alpha=0.5)
# plt.title('Scatter Plot of Quantity vs. Price')
# plt.xlabel('Quantity')
# plt.ylabel('Price')
# plt.grid(True)
# plt.show()

# %%
data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1067371 entries, 0 to 541909
# Data columns (total 8 columns):
#  #   Column       Non-Null Count    Dtype
# ---  ------       --------------    -----
#  0   Invoice      1067371 non-null  object
#  1   StockCode    1067371 non-null  object
#  2   Description  1062989 non-null  object
#  3   Quantity     1067371 non-null  int64
#  4   InvoiceDate  1067371 non-null  datetime64[ns]
#  5   Price        1067371 non-null  float64
#  6   Customer ID  824364 non-null   float64
#  7   Country      1067371 non-null  object
# dtypes: datetime64[ns](1), float64(2), int64(1), object(4)
# memory usage: 73.3+ MB

# %%
data_df.isnull().sum()
# Out:
# Invoice             0
# StockCode           0
# Description      4382
# Quantity            0
# InvoiceDate         0
# Price               0
# Customer ID    243007
# Country             0
# dtype: int64

# %%
plt.figure(figsize=(10, 6))
sns.heatmap(data_df.isnull(), cmap='viridis', cbar=False)
plt.title('Missing Values Heatmap')
plt.show()

# %% [markdown]
# The forward fill method is used because customer IDs are grouped together, so its more accurate to use the forward method for accuracy of data.

# %%
data_df['Customer ID'].fillna(method='ffill',inplace=True)

# %% [markdown]
# Unknown is used to fill missing values because every product is unique and is text based so the use of the mode or forward fill would create some bias in the dataset analysis.

# %%
data_df['Description'].fillna('Unknown',inplace=True)

# %%
data_df.isnull().sum()
# Out:
# Invoice        0
# StockCode      0
# Description    0
# Quantity       0
# InvoiceDate    0
# Price          0
# Customer ID    0
# Country        0
# dtype: int64

# %%
data_df['Country'].unique()
# Out:
# array(['United Kingdom', 'France', 'USA', 'Belgium', 'Australia', 'EIRE',
#        'Germany', 'Portugal', 'Japan', 'Denmark', 'Nigeria',
#        'Netherlands', 'Poland', 'Spain', 'Channel Islands', 'Italy',
#        'Cyprus', 'Greece', 'Norway', 'Austria', 'Sweden',
#        'United Arab Emirates', 'Finland', 'Switzerland', 'Unspecified',
#        'Malta', 'Bahrain', 'RSA', 'Bermuda', 'Hong Kong', 'Singapore',
#        'Thailand', 'Israel', 'Lithuania', 'West Indies', 'Lebanon',
#        'Korea', 'Brazil', 'Canada', 'Iceland', 'Saudi Arabia',
#        'Czech Republic', 'European Community'], dtype=object)

# %% [markdown]
# Label encoder to be used to transform Country from a categorical feature into a numerical feature to be able to use it in clustering.

# %%
from sklearn.preprocessing import LabelEncoder

# %%
label = LabelEncoder()

# %%
encoded_data_df['New Country']=label.fit_transform(data_df['Country'])

# %%
data_df.reset_index(drop=True, inplace=True)
new_data = pd.concat([pd.DataFrame(encoded_data_df, columns=['New Country']), data_df], axis=1)

# %%
new_data.head()
# Out:
#    New Country Invoice StockCode                          Description  \
# 0           40  489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS
# 1           40  489434    79323P                   PINK CHERRY LIGHTS
# 2           40  489434    79323W                  WHITE CHERRY LIGHTS
# 3           40  489434     22041         RECORD FRAME 7" SINGLE SIZE
# 4           40  489434     21232       STRAWBERRY CERAMIC TRINKET BOX
#
#    Quantity         InvoiceDate  Price  Customer ID         Country
# 0        12 2009-12-01 07:45:00   6.95      13085.0  United Kingdom
# 1        12 2009-12-01 07:45:00   6.75      13085.0  United Kingdom
# 2        12 2009-12-01 07:45:00   6.75      13085.0  United Kingdom
# 3        48 2009-12-01 07:45:00   2.10      13085.0  United Kingdom
# 4        24 2009-12-01 07:45:00   1.25      13085.0  United Kingdom

# %%
new_data.drop(['Country'],axis=1,inplace=True)

# %%
new_data.head()
# Out:
#    New Country Invoice StockCode                          Description  \
# 0           40  489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS
# 1           40  489434    79323P                   PINK CHERRY LIGHTS
# 2           40  489434    79323W                  WHITE CHERRY LIGHTS
# 3           40  489434     22041         RECORD FRAME 7" SINGLE SIZE
# 4           40  489434     21232       STRAWBERRY CERAMIC TRINKET BOX
#
#    Quantity         InvoiceDate  Price  Customer ID
# 0        12 2009-12-01 07:45:00   6.95      13085.0
# 1        12 2009-12-01 07:45:00   6.75      13085.0
# 2        12 2009-12-01 07:45:00   6.75      13085.0
# 3        48 2009-12-01 07:45:00   2.10      13085.0
# 4        24 2009-12-01 07:45:00   1.25      13085.0

# %% [markdown]
# Drop categorical data and create a new dataset that consists of three features that will be clustered.

# %%
columns_df = new_data[['Quantity', 'Price', 'New Country']]

# %%
for i in columns_df:
    plt.figure()
    sns.distplot(new_data[i])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/Documents/anaconda3/lib/python3.11/site-packages/pandas/core/indexes/base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File ~/Documents/anaconda3/lib/python3.11/site-packages/pandas/_libs/index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/Documents/anaconda3/lib/python3.11/site-packages/pandas/_libs/index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Cluster'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %% [markdown]
# Using standard scaler to improve the performance of algorithms.

# %%
scaler = StandardScaler()
scaled = scaler.fit_transform(columns_df)

# %%
columns_df.head()
# Out:
#    Quantity  Price  New Country
# 0        12   6.95           40
# 1        12   6.75           40
# 2        12   6.75           40
# 3        48   2.10           40
# 4        24   1.25           40

# %%
kmeans = KMeans(n_clusters=3, n_init=10, random_state=42)
k_clusters = kmeans.fit_predict(scaled)

# %%
wcss = []
for k in range(2, 10):
    kmeans = KMeans(n_clusters=k, n_init=10, random_state=42)
    kmeans.fit(columns_df)
    wcss.append(kmeans.inertia_)
print(wcss)
# Out:
# [36132008020.05288, 24090043554.786243, 17649616564.996357, 11433012382.987303, 8406232670.876859, 6795863809.997386, 5366929455.958663, 4575784310.430313]

# %%
plt.plot(range(2,10), wcss);

# %%
columns_df['Cluster'] = kmeans.labels_

# %%
def plotFeatures(col1, col2):
    plt.scatter(
        columns_df[kmeans.labels_ == 0].iloc[:, col1],
        columns_df[kmeans.labels_ == 0].iloc[:, col2],
        s=50,
        c='red',
        label='Cluster 1'
    )
    plt.scatter(
        columns_df[kmeans.labels_ == 1].iloc[:, col1],
        columns_df[kmeans.labels_ == 1].iloc[:, col2],
        s=50,
        c='blue',
        label='Cluster 2'
    )
    plt.scatter(
        columns_df[kmeans.labels_ == 2].iloc[:, col1],
        columns_df[kmeans.labels_ == 2].iloc[:, col2],
        s=50,
        c='green',
        label='Cluster 3'
    )
    plt.scatter(
        kmeans.cluster_centers_[:, col1],
        kmeans.cluster_centers_[:, col2],
        s=100,
        c='yellow',
        label='Centroids'
    )
    plt.xlabel(columns_df.columns[col1])
    plt.ylabel(columns_df.columns[col2])
    plt.legend()
    plt.title('Clustering based on ' + columns_df.columns[col1] + ' and ' + columns_df.columns[col2])
    plt.show()

plotFeatures(0, 1)

# %%
plotFeatures(0,2)

# %%
plotFeatures(1,2)

# %% [markdown]
# kmeans = KMeans(n_clusters=3,n_init=10,random_state=42)

# %% [markdown]
# y_pred = kmeans.fit_predict(x)

# %% [markdown]
# y_pred

# %% [markdown]
# wcss = []
# for k in range(2,10):
#     kmeans = KMeans(n_clusters=k,n_init=10,random_state=42)
#     kmeans.fit(x)
#     wcss.append(kmeans.inertia_)
# print(wcss)

# %% [markdown]
# plt.plot(range(2,10),wcss);

# %% [markdown]
# silhouette_score(x,y_pred)

# %%
data_df.head()
# Out:
#   Invoice StockCode                          Description  Quantity  \
# 0  489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1  489434    79323P                   PINK CHERRY LIGHTS        12
# 2  489434    79323W                  WHITE CHERRY LIGHTS        12
# 3  489434     22041         RECORD FRAME 7" SINGLE SIZE         48
# 4  489434     21232       STRAWBERRY CERAMIC TRINKET BOX        24
#
#           InvoiceDate  Price  Customer ID         Country
# 0 2009-12-01 07:45:00   6.95      13085.0  United Kingdom
# 1 2009-12-01 07:45:00   6.75      13085.0  United Kingdom
# 2 2009-12-01 07:45:00   6.75      13085.0  United Kingdom
# 3 2009-12-01 07:45:00   2.10      13085.0  United Kingdom
# 4 2009-12-01 07:45:00   1.25      13085.0  United Kingdom

# %%
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
from sklearn_extra.cluster import KMedoids

# %%
df = data_df[['Quantity','Price']]

# %%
df.head()
# Out:
#    Quantity  Price
# 0        12   6.95
# 1        12   6.75
# 2        12   6.75
# 3        48   2.10
# 4        24   1.25

# %%
standard = StandardScaler()

# %%
x = standard.fit_transform(df)

# %%
coumns = df.columns

# %%
coumns
# Out:
# Index(['Quantity', 'Price'], dtype='object')

# %%
df = pd.DataFrame(standard.fit_transform(df),columns=coumns)

# %%
df.head()
# Out:
#    Quantity     Price
# 0  0.011934  0.018620
# 1  0.011934  0.017002
# 2  0.011934  0.017002
# 3  0.220381 -0.020634
# 4  0.081417 -0.027514

# %% [markdown]
# K-elbow method

# %%
wcss = []
for k in range (2,10):
    kmeans = KMeans(n_clusters = k,random_state=42)
    kmeans.fit(x)
    wcss.append(kmeans.inertia_)
plt.plot(range(2,10),wcss);
# Out:
# /Users/alaashammar/Documents/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /Users/alaashammar/Documents/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /Users/alaashammar/Documents/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# ...

# %% [markdown]
# Silhouette Score

# %% [markdown]
# wcss = []
# for k in range (2,10):
#     kmeans = KMeans(n_clusters = k,random_state=42)
#     y_kmeans = kmeans.fit_predict(df)
#     wcss.append(silhouette_score(df,y_kmeans))
# plt.plot(range(2,10),wcss);
